# %%
import pycaret
print('PyCaret: %s' % pycaret.__version__)
# Out:
# PyCaret: 2.3.1

# %% [raw]
# # Link to task Steps: https://machinelearningmastery.com/pycaret-for-machine-learning/

# %%
...
import pandas as pd
# define the location of the dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv'
# load the dataset
df = pd.read_csv(url, header=None)
# summarize the shape of the dataset
print(df.shape)
# Out:
# (208, 61)

# %%
# set column names as the column number
n_cols = df.shape[1]
df.columns = [str(i) for i in range(n_cols)]

# %%
# summarize the first few rows of data
print(df.head())
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9  ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
#import classification module 
from pycaret.classification import *

# %%
# setup the dataset
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)

# %%
# evaluate models and compare models
best = compare_models()
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr  Logistic Regression       0.8  0.8946     0.8  0.8206  0.7897  0.6025
#
#        MCC  TT (Sec)
# lr  0.6265      0.62
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.8000  0.8946  0.8000  0.8206  0.7897  0.6025
# knn  K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671  0.7019  0.4722
#
#         MCC  TT (Sec)
# lr   0.6265     0.620
# knn  0.4813     0.015
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.8000  0.8946  0.8000  0.8206  0.7897  0.6025
# knn  K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671  0.7019  0.4722
# nb              Naive Bayes    0.7176  0.8173  0.8000  0.6847  0.7306  0.4400
#
#         MCC  TT (Sec)
# lr   0.6265     0.620
# knn  0.4813     0.015
# nb   0.4566     0.006
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.8000  0.8946  0.8000  0.8206  0.7897
# dt   Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974  0.7658
# knn    K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671  0.7019
# nb                Naive Bayes    0.7176  0.8173  0.8000  0.6847  0.7306
#
#       Kappa     MCC  TT (Sec)
# lr   0.6025  0.6265     0.620
# dt   0.5710  0.5842     0.007
# knn  0.4722  0.4813     0.015
# nb   0.4400  0.4566     0.006
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.8000  0.8946  0.8000  0.8206  0.7897
# dt   Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974  0.7658
# svm       SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542  0.7184
# knn    K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671  0.7019
# nb                Naive Bayes    0.7176  0.8173  0.8000  0.6847  0.7306
#
#       Kappa     MCC  TT (Sec)
# lr   0.6025  0.6265     0.620
# dt   0.5710  0.5842     0.007
# svm  0.5284  0.5694     0.006
# knn  0.4722  0.4813     0.015
# nb   0.4400  0.4566     0.006
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr          Logistic Regression    0.8000  0.8946  0.8000  0.8206  0.7897
# ridge          Ridge Classifier    0.7929  0.0000  0.7714  0.8206  0.7684
# dt     Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974  0.7658
# svm         SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542  0.7184
# knn      K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671  0.7019
# nb                  Naive Bayes    0.7176  0.8173  0.8000  0.6847  0.7306
#
#         Kappa     MCC  TT (Sec)
# lr     0.6025  0.6265     0.620
# ridge  0.5873  0.6118     0.006
# dt     0.5710  0.5842     0.007
# svm    0.5284  0.5694     0.006
# knn    0.4722  0.4813     0.015
# nb     0.4400  0.4566     0.006
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# rf     Random Forest Classifier    0.8486  0.9436  0.8143  0.8798  0.8337
# lr          Logistic Regression    0.8000  0.8946  0.8000  0.8206  0.7897
# ridge          Ridge Classifier    0.7929  0.0000  0.7714  0.8206  0.7684
# dt     Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974  0.7658
# svm         SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542  0.7184
# knn      K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671  0.7019
# nb                  Naive Bayes    0.7176  0.8173  0.8000  0.6847  0.7306
#
#         Kappa     MCC  TT (Sec)
# rf     0.6971  0.7151     0.090
# lr     0.6025  0.6265     0.620
# ridge  0.5873  0.6118     0.006
# dt     0.5710  0.5842     0.007
# svm    0.5284  0.5694     0.006
# knn    0.4722  0.4813     0.015
# nb     0.4400  0.4566     0.006
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.8486  0.9436  0.8143  0.8798
# lr                 Logistic Regression    0.8000  0.8946  0.8000  0.8206
# ridge                 Ridge Classifier    0.7929  0.0000  0.7714  0.8206
# dt            Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974
# svm                SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542
# knn             K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671
# nb                         Naive Bayes    0.7176  0.8173  0.8000  0.6847
# qda    Quadratic Discriminant Analysis    0.6338  0.6048  0.3857  0.7500
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.8337  0.6971  0.7151     0.090
# lr     0.7897  0.6025  0.6265     0.620
# ridge  0.7684  0.5873  0.6118     0.006
# dt     0.7658  0.5710  0.5842     0.007
# svm    0.7184  0.5284  0.5694     0.006
# knn    0.7019  0.4722  0.4813     0.015
# nb     0.7306  0.4400  0.4566     0.006
# qda    0.4854  0.2586  0.2991     0.008
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.8486  0.9436  0.8143  0.8798
# ada               Ada Boost Classifier    0.8214  0.9133  0.7857  0.8536
# lr                 Logistic Regression    0.8000  0.8946  0.8000  0.8206
# ridge                 Ridge Classifier    0.7929  0.0000  0.7714  0.8206
# dt            Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974
# svm                SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542
# knn             K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671
# nb                         Naive Bayes    0.7176  0.8173  0.8000  0.6847
# qda    Quadratic Discriminant Analysis    0.6338  0.6048  0.3857  0.7500
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.8337  0.6971  0.7151     0.090
# ada    0.8080  0.6430  0.6570     0.046
# lr     0.7897  0.6025  0.6265     0.620
# ridge  0.7684  0.5873  0.6118     0.006
# dt     0.7658  0.5710  0.5842     0.007
# svm    0.7184  0.5284  0.5694     0.006
# knn    0.7019  0.4722  0.4813     0.015
# nb     0.7306  0.4400  0.4566     0.006
# qda    0.4854  0.2586  0.2991     0.008
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# gbc       Gradient Boosting Classifier    0.8762  0.9418  0.8714  0.8855
# rf            Random Forest Classifier    0.8486  0.9436  0.8143  0.8798
# ada               Ada Boost Classifier    0.8214  0.9133  0.7857  0.8536
# lr                 Logistic Regression    0.8000  0.8946  0.8000  0.8206
# ridge                 Ridge Classifier    0.7929  0.0000  0.7714  0.8206
# dt            Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974
# svm                SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542
# knn             K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671
# nb                         Naive Bayes    0.7176  0.8173  0.8000  0.6847
# qda    Quadratic Discriminant Analysis    0.6338  0.6048  0.3857  0.7500
#
#            F1   Kappa     MCC  TT (Sec)
# gbc    0.8721  0.7532  0.7636     0.067
# rf     0.8337  0.6971  0.7151     0.090
# ada    0.8080  0.6430  0.6570     0.046
# lr     0.7897  0.6025  0.6265     0.620
# ridge  0.7684  0.5873  0.6118     0.006
# dt     0.7658  0.5710  0.5842     0.007
# svm    0.7184  0.5284  0.5694     0.006
# knn    0.7019  0.4722  0.4813     0.015
# nb     0.7306  0.4400  0.4566     0.006
# qda    0.4854  0.2586  0.2991     0.008
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# gbc       Gradient Boosting Classifier    0.8762  0.9418  0.8714  0.8855
# rf            Random Forest Classifier    0.8486  0.9436  0.8143  0.8798
# ada               Ada Boost Classifier    0.8214  0.9133  0.7857  0.8536
# lr                 Logistic Regression    0.8000  0.8946  0.8000  0.8206
# ridge                 Ridge Classifier    0.7929  0.0000  0.7714  0.8206
# dt            Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974
# svm                SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542
# knn             K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671
# nb                         Naive Bayes    0.7176  0.8173  0.8000  0.6847
# lda       Linear Discriminant Analysis    0.7171  0.7908  0.6857  0.7615
# qda    Quadratic Discriminant Analysis    0.6338  0.6048  0.3857  0.7500
#
#            F1   Kappa     MCC  TT (Sec)
# gbc    0.8721  0.7532  0.7636     0.067
# rf     0.8337  0.6971  0.7151     0.090
# ada    0.8080  0.6430  0.6570     0.046
# lr     0.7897  0.6025  0.6265     0.620
# ridge  0.7684  0.5873  0.6118     0.006
# dt     0.7658  0.5710  0.5842     0.007
# svm    0.7184  0.5284  0.5694     0.006
# knn    0.7019  0.4722  0.4813     0.015
# nb     0.7306  0.4400  0.4566     0.006
# lda    0.6800  0.4355  0.4642     0.007
# qda    0.4854  0.2586  0.2991     0.008
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# et              Extra Trees Classifier    0.8886  0.9625  0.8429  0.9325
# gbc       Gradient Boosting Classifier    0.8762  0.9418  0.8714  0.8855
# rf            Random Forest Classifier    0.8486  0.9436  0.8143  0.8798
# ada               Ada Boost Classifier    0.8214  0.9133  0.7857  0.8536
# lr                 Logistic Regression    0.8000  0.8946  0.8000  0.8206
# ridge                 Ridge Classifier    0.7929  0.0000  0.7714  0.8206
# dt            Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974
# svm                SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542
# knn             K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671
# nb                         Naive Bayes    0.7176  0.8173  0.8000  0.6847
# lda       Linear Discriminant Analysis    0.7171  0.7908  0.6857  0.7615
# qda    Quadratic Discriminant Analysis    0.6338  0.6048  0.3857  0.7500
#
#            F1   Kappa     MCC  TT (Sec)
# et     0.8778  0.7770  0.7898     0.076
# gbc    0.8721  0.7532  0.7636     0.067
# rf     0.8337  0.6971  0.7151     0.090
# ada    0.8080  0.6430  0.6570     0.046
# lr     0.7897  0.6025  0.6265     0.620
# ridge  0.7684  0.5873  0.6118     0.006
# dt     0.7658  0.5710  0.5842     0.007
# svm    0.7184  0.5284  0.5694     0.006
# knn    0.7019  0.4722  0.4813     0.015
# nb     0.7306  0.4400  0.4566     0.006
# lda    0.6800  0.4355  0.4642     0.007
# qda    0.4854  0.2586  0.2991     0.008
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9110  0.9592  0.8714  0.9533
# et                 Extra Trees Classifier    0.8886  0.9625  0.8429  0.9325
# gbc          Gradient Boosting Classifier    0.8762  0.9418  0.8714  0.8855
# rf               Random Forest Classifier    0.8486  0.9436  0.8143  0.8798
# ada                  Ada Boost Classifier    0.8214  0.9133  0.7857  0.8536
# lr                    Logistic Regression    0.8000  0.8946  0.8000  0.8206
# ridge                    Ridge Classifier    0.7929  0.0000  0.7714  0.8206
# dt               Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974
# svm                   SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542
# knn                K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671
# nb                            Naive Bayes    0.7176  0.8173  0.8000  0.6847
# lda          Linear Discriminant Analysis    0.7171  0.7908  0.6857  0.7615
# qda       Quadratic Discriminant Analysis    0.6338  0.6048  0.3857  0.7500
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.9016  0.8216  0.8374     0.145
# et        0.8778  0.7770  0.7898     0.076
# gbc       0.8721  0.7532  0.7636     0.067
# rf        0.8337  0.6971  0.7151     0.090
# ada       0.8080  0.6430  0.6570     0.046
# lr        0.7897  0.6025  0.6265     0.620
# ridge     0.7684  0.5873  0.6118     0.006
# dt        0.7658  0.5710  0.5842     0.007
# svm       0.7184  0.5284  0.5694     0.006
# knn       0.7019  0.4722  0.4813     0.015
# nb        0.7306  0.4400  0.4566     0.006
# lda       0.6800  0.4355  0.4642     0.007
# qda       0.4854  0.2586  0.2991     0.008
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9110  0.9592  0.8714  0.9533
# et                 Extra Trees Classifier    0.8886  0.9625  0.8429  0.9325
# gbc          Gradient Boosting Classifier    0.8762  0.9418  0.8714  0.8855
# rf               Random Forest Classifier    0.8486  0.9436  0.8143  0.8798
# ada                  Ada Boost Classifier    0.8214  0.9133  0.7857  0.8536
# lr                    Logistic Regression    0.8000  0.8946  0.8000  0.8206
# ridge                    Ridge Classifier    0.7929  0.0000  0.7714  0.8206
# dt               Decision Tree Classifier    0.7848  0.7866  0.7571  0.7974
# svm                   SVM - Linear Kernel    0.7643  0.0000  0.6714  0.8542
# knn                K Neighbors Classifier    0.7371  0.8523  0.6571  0.7671
# nb                            Naive Bayes    0.7176  0.8173  0.8000  0.6847
# lda          Linear Discriminant Analysis    0.7171  0.7908  0.6857  0.7615
# qda       Quadratic Discriminant Analysis    0.6338  0.6048  0.3857  0.7500
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.9016  0.8216  0.8374     0.145
# et        0.8778  0.7770  0.7898     0.076
# gbc       0.8721  0.7532  0.7636     0.067
# rf        0.8337  0.6971  0.7151     0.090
# ada       0.8080  0.6430  0.6570     0.046
# lr        0.7897  0.6025  0.6265     0.620
# ridge     0.7684  0.5873  0.6118     0.006
# dt        0.7658  0.5710  0.5842     0.007
# svm       0.7184  0.5284  0.5694     0.006
# knn       0.7019  0.4722  0.4813     0.015
# nb        0.7306  0.4400  0.4566     0.006
# lda       0.6800  0.4355  0.4642     0.007
# qda       0.4854  0.2586  0.2991     0.008

# %%
# compare machine learning algorithms on the sonar classification dataset
from pandas import read_csv
from pycaret.classification import setup
from pycaret.classification import compare_models
# define the location of the dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv'
# load the dataset
df = read_csv(url, header=None)
# set column names as the column number
n_cols = df.shape[1]
df.columns = [str(i) for i in range(n_cols)]
# setup the dataset
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)
# evaluate models and compare models
best = compare_models()
# report the best model
print(best)
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr  Logistic Regression    0.7533  0.8438  0.6262  0.8052  0.6878  0.4938
#
#        MCC  TT (Sec)
# lr  0.5167     0.008
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.7533  0.8438  0.6262  0.8052  0.6878  0.4938
# knn  K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579  0.7067  0.4946
#
#         MCC  TT (Sec)
# lr   0.5167     0.008
# knn  0.5084     0.013
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# lr      Logistic Regression    0.7533  0.8438  0.6262  0.8052  0.6878  0.4938
# knn  K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579  0.7067  0.4946
# nb              Naive Bayes    0.6700  0.7824  0.8167  0.6185  0.6996  0.3557
#
#         MCC  TT (Sec)
# lr   0.5167     0.008
# knn  0.5084     0.013
# nb   0.3653     0.006
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.7533  0.8438  0.6262  0.8052  0.6878
# knn    K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579  0.7067
# dt   Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121  0.6750
# nb                Naive Bayes    0.6700  0.7824  0.8167  0.6185  0.6996
#
#       Kappa     MCC  TT (Sec)
# lr   0.4938  0.5167     0.008
# knn  0.4946  0.5084     0.013
# dt   0.4186  0.4424     0.007
# nb   0.3557  0.3653     0.006
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# lr        Logistic Regression    0.7533  0.8438  0.6262  0.8052  0.6878
# knn    K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579  0.7067
# svm       SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472  0.6981
# dt   Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121  0.6750
# nb                Naive Bayes    0.6700  0.7824  0.8167  0.6185  0.6996
#
#       Kappa     MCC  TT (Sec)
# lr   0.4938  0.5167     0.008
# knn  0.4946  0.5084     0.013
# svm  0.4410  0.4733     0.007
# dt   0.4186  0.4424     0.007
# nb   0.3557  0.3653     0.006
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# ridge          Ridge Classifier    0.7548  0.0000  0.6762  0.7586  0.7019
# lr          Logistic Regression    0.7533  0.8438  0.6262  0.8052  0.6878
# knn      K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579  0.7067
# svm         SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472  0.6981
# dt     Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121  0.6750
# nb                  Naive Bayes    0.6700  0.7824  0.8167  0.6185  0.6996
#
#         Kappa     MCC  TT (Sec)
# ridge  0.5003  0.5110     0.007
# lr     0.4938  0.5167     0.008
# knn    0.4946  0.5084     0.013
# svm    0.4410  0.4733     0.007
# dt     0.4186  0.4424     0.007
# nb     0.3557  0.3653     0.006
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# rf     Random Forest Classifier    0.8148  0.9126  0.7143  0.8726  0.7744
# ridge          Ridge Classifier    0.7548  0.0000  0.6762  0.7586  0.7019
# lr          Logistic Regression    0.7533  0.8438  0.6262  0.8052  0.6878
# knn      K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579  0.7067
# svm         SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472  0.6981
# dt     Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121  0.6750
# nb                  Naive Bayes    0.6700  0.7824  0.8167  0.6185  0.6996
#
#         Kappa     MCC  TT (Sec)
# rf     0.6215  0.6393     0.095
# ridge  0.5003  0.5110     0.007
# lr     0.4938  0.5167     0.008
# knn    0.4946  0.5084     0.013
# svm    0.4410  0.4733     0.007
# dt     0.4186  0.4424     0.007
# nb     0.3557  0.3653     0.006
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.8148  0.9126  0.7143  0.8726
# ridge                 Ridge Classifier    0.7548  0.0000  0.6762  0.7586
# lr                 Logistic Regression    0.7533  0.8438  0.6262  0.8052
# knn             K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579
# svm                SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472
# dt            Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121
# nb                         Naive Bayes    0.6700  0.7824  0.8167  0.6185
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.7744  0.6215  0.6393     0.095
# ridge  0.7019  0.5003  0.5110     0.007
# lr     0.6878  0.4938  0.5167     0.008
# knn    0.7067  0.4946  0.5084     0.013
# svm    0.6981  0.4410  0.4733     0.007
# dt     0.6750  0.4186  0.4424     0.007
# nb     0.6996  0.3557  0.3653     0.006
# qda    0.0000  0.0000  0.0000     0.007
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.8148  0.9126  0.7143  0.8726
# ada               Ada Boost Classifier    0.8067  0.8699  0.7738  0.8089
# ridge                 Ridge Classifier    0.7548  0.0000  0.6762  0.7586
# lr                 Logistic Regression    0.7533  0.8438  0.6262  0.8052
# knn             K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579
# svm                SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472
# dt            Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121
# nb                         Naive Bayes    0.6700  0.7824  0.8167  0.6185
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.7744  0.6215  0.6393     0.095
# ada    0.7803  0.6089  0.6204     0.044
# ridge  0.7019  0.5003  0.5110     0.007
# lr     0.6878  0.4938  0.5167     0.008
# knn    0.7067  0.4946  0.5084     0.013
# svm    0.6981  0.4410  0.4733     0.007
# dt     0.6750  0.4186  0.4424     0.007
# nb     0.6996  0.3557  0.3653     0.006
# qda    0.0000  0.0000  0.0000     0.007
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.8148  0.9126  0.7143  0.8726
# gbc       Gradient Boosting Classifier    0.8081  0.8850  0.7595  0.8306
# ada               Ada Boost Classifier    0.8067  0.8699  0.7738  0.8089
# ridge                 Ridge Classifier    0.7548  0.0000  0.6762  0.7586
# lr                 Logistic Regression    0.7533  0.8438  0.6262  0.8052
# knn             K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579
# svm                SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472
# dt            Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121
# nb                         Naive Bayes    0.6700  0.7824  0.8167  0.6185
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.7744  0.6215  0.6393     0.095
# gbc    0.7861  0.6127  0.6229     0.068
# ada    0.7803  0.6089  0.6204     0.044
# ridge  0.7019  0.5003  0.5110     0.007
# lr     0.6878  0.4938  0.5167     0.008
# knn    0.7067  0.4946  0.5084     0.013
# svm    0.6981  0.4410  0.4733     0.007
# dt     0.6750  0.4186  0.4424     0.007
# nb     0.6996  0.3557  0.3653     0.006
# qda    0.0000  0.0000  0.0000     0.007
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.8148  0.9126  0.7143  0.8726
# gbc       Gradient Boosting Classifier    0.8081  0.8850  0.7595  0.8306
# ada               Ada Boost Classifier    0.8067  0.8699  0.7738  0.8089
# ridge                 Ridge Classifier    0.7548  0.0000  0.6762  0.7586
# lr                 Logistic Regression    0.7533  0.8438  0.6262  0.8052
# knn             K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579
# svm                SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472
# dt            Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121
# lda       Linear Discriminant Analysis    0.6833  0.7654  0.6238  0.6762
# nb                         Naive Bayes    0.6700  0.7824  0.8167  0.6185
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# rf     0.7744  0.6215  0.6393     0.095
# gbc    0.7861  0.6127  0.6229     0.068
# ada    0.7803  0.6089  0.6204     0.044
# ridge  0.7019  0.5003  0.5110     0.007
# lr     0.6878  0.4938  0.5167     0.008
# knn    0.7067  0.4946  0.5084     0.013
# svm    0.6981  0.4410  0.4733     0.007
# dt     0.6750  0.4186  0.4424     0.007
# lda    0.6320  0.3591  0.3728     0.007
# nb     0.6996  0.3557  0.3653     0.006
# qda    0.0000  0.0000  0.0000     0.007
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# et              Extra Trees Classifier    0.8490  0.9347  0.7595  0.9038
# rf            Random Forest Classifier    0.8148  0.9126  0.7143  0.8726
# gbc       Gradient Boosting Classifier    0.8081  0.8850  0.7595  0.8306
# ada               Ada Boost Classifier    0.8067  0.8699  0.7738  0.8089
# ridge                 Ridge Classifier    0.7548  0.0000  0.6762  0.7586
# lr                 Logistic Regression    0.7533  0.8438  0.6262  0.8052
# knn             K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579
# svm                SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472
# dt            Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121
# lda       Linear Discriminant Analysis    0.6833  0.7654  0.6238  0.6762
# nb                         Naive Bayes    0.6700  0.7824  0.8167  0.6185
# qda    Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#            F1   Kappa     MCC  TT (Sec)
# et     0.8157  0.6904  0.7071     0.086
# rf     0.7744  0.6215  0.6393     0.095
# gbc    0.7861  0.6127  0.6229     0.068
# ada    0.7803  0.6089  0.6204     0.044
# ridge  0.7019  0.5003  0.5110     0.007
# lr     0.6878  0.4938  0.5167     0.008
# knn    0.7067  0.4946  0.5084     0.013
# svm    0.6981  0.4410  0.4733     0.007
# dt     0.6750  0.4186  0.4424     0.007
# lda    0.6320  0.3591  0.3728     0.007
# nb     0.6996  0.3557  0.3653     0.006
# qda    0.0000  0.0000  0.0000     0.007
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.8490  0.9347  0.7595  0.9038
# lightgbm  Light Gradient Boosting Machine    0.8281  0.9134  0.7738  0.8556
# rf               Random Forest Classifier    0.8148  0.9126  0.7143  0.8726
# gbc          Gradient Boosting Classifier    0.8081  0.8850  0.7595  0.8306
# ada                  Ada Boost Classifier    0.8067  0.8699  0.7738  0.8089
# ridge                    Ridge Classifier    0.7548  0.0000  0.6762  0.7586
# lr                    Logistic Regression    0.7533  0.8438  0.6262  0.8052
# knn                K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579
# svm                   SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472
# dt               Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121
# lda          Linear Discriminant Analysis    0.6833  0.7654  0.6238  0.6762
# nb                            Naive Bayes    0.6700  0.7824  0.8167  0.6185
# qda       Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.8157  0.6904  0.7071     0.086
# lightgbm  0.7910  0.6488  0.6680     0.015
# rf        0.7744  0.6215  0.6393     0.095
# gbc       0.7861  0.6127  0.6229     0.068
# ada       0.7803  0.6089  0.6204     0.044
# ridge     0.7019  0.5003  0.5110     0.007
# lr        0.6878  0.4938  0.5167     0.008
# knn       0.7067  0.4946  0.5084     0.013
# svm       0.6981  0.4410  0.4733     0.007
# dt        0.6750  0.4186  0.4424     0.007
# lda       0.6320  0.3591  0.3728     0.007
# nb        0.6996  0.3557  0.3653     0.006
# qda       0.0000  0.0000  0.0000     0.007
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.8490  0.9347  0.7595  0.9038
# lightgbm  Light Gradient Boosting Machine    0.8281  0.9134  0.7738  0.8556
# rf               Random Forest Classifier    0.8148  0.9126  0.7143  0.8726
# gbc          Gradient Boosting Classifier    0.8081  0.8850  0.7595  0.8306
# ada                  Ada Boost Classifier    0.8067  0.8699  0.7738  0.8089
# ridge                    Ridge Classifier    0.7548  0.0000  0.6762  0.7586
# lr                    Logistic Regression    0.7533  0.8438  0.6262  0.8052
# knn                K Neighbors Classifier    0.7519  0.8035  0.6833  0.7579
# svm                   SVM - Linear Kernel    0.7195  0.0000  0.7286  0.7472
# dt               Decision Tree Classifier    0.7119  0.7104  0.6833  0.7121
# lda          Linear Discriminant Analysis    0.6833  0.7654  0.6238  0.6762
# nb                            Naive Bayes    0.6700  0.7824  0.8167  0.6185
# qda       Quadratic Discriminant Analysis    0.5452  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.8157  0.6904  0.7071     0.086
# lightgbm  0.7910  0.6488  0.6680     0.015
# rf        0.7744  0.6215  0.6393     0.095
# gbc       0.7861  0.6127  0.6229     0.068
# ada       0.7803  0.6089  0.6204     0.044
# ridge     0.7019  0.5003  0.5110     0.007
# lr        0.6878  0.4938  0.5167     0.008
# knn       0.7067  0.4946  0.5084     0.013
# svm       0.6981  0.4410  0.4733     0.007
# dt        0.6750  0.4186  0.4424     0.007
# lda       0.6320  0.3591  0.3728     0.007
# nb        0.6996  0.3557  0.3653     0.006
# qda       0.0000  0.0000  0.0000     0.007
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=5858, verbose=0,
#                      warm_start=False)

# %%
# Tuning Machine Learning Models
# setup the dataset
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)

# %%
# tune model hyperparameters
from sklearn.ensemble import ExtraTreesClassifier
best = tune_model(ExtraTreesClassifier(), n_iter=200)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 2000 out of 2000 | elapsed:  3.5min finished
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9333  0.9821  1.0000  0.8750  0.9333  0.8673  0.8750
# 1       0.8667  0.9107  0.7143  1.0000  0.8333  0.7273  0.7559
# 2       0.7333  0.8571  1.0000  0.6364  0.7778  0.4828  0.5641
# 3       0.8000  0.9643  0.8571  0.7500  0.8000  0.6018  0.6071
# 4       0.8000  0.9821  0.5714  1.0000  0.7273  0.5872  0.6447
# 5       0.8571  0.9792  0.6667  1.0000  0.8000  0.6957  0.7303
# 6       0.9286  1.0000  0.8571  1.0000  0.9231  0.8571  0.8660
# 7       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 8       0.8571  0.8980  1.0000  0.7778  0.8750  0.7143  0.7454
# 9       0.8571  0.9796  0.8571  0.8571  0.8571  0.7143  0.7143
# Mean    0.8633  0.9553  0.8524  0.8896  0.8527  0.7248  0.7503
# SD      0.0727  0.0465  0.1482  0.1258  0.0781  0.1440  0.1262
